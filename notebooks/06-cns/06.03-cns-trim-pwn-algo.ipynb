# %%
# %load_ext autoreload
# %autoreload 2
from mesh_import import mesh
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import igraph as ig
from CwnGraph import CwnBase, CwnSense, CwnFacet
from tqdm.autonotebook import tqdm

# %%
testG = ig.Graph(directed=True)
testG.add_vertices(10)
testG.add_edges([[4,3],[3,2],[2,1],[1,0],[5,1],[6,3],[7,1],[8,7],[9,7],[1,5],[3,6],[7,9]])
for idx in [0,1,2,3,4,7,8]:
    testG.vs[idx]["pwn"] = "pwn"

# %%
mesh.draw_igraph(testG)

# %%
mesh.trim_pwn(testG)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=7.0), HTML(value='')))
# igraph.Vertex(<igraph.Graph object at 0x00000166B0DAFE50>, 6, {'pwn': None}) igraph.Vertex(<igraph.Graph object at 0x00000166B0DAFE50>, 5, {'pwn': None})
# igraph.Vertex(<igraph.Graph object at 0x00000166B0DAFE50>, 9, {'pwn': None}) igraph.Vertex(<igraph.Graph object at 0x00000166B0DAFE50>, 5, {'pwn': None})
# E:\LangOn\OntoDeepLex\src\mesh\cns.py:152: RuntimeWarning: Couldn't reach some vertices at c:\projects\python-igraph-jst2e\vendor\build\igraph\igraph-0.9.0-pre+0afacadd-msvc\src\structural_properties.c:768
#   #     breakpoint()
# E:\LangOn\OntoDeepLex\src\mesh\cns.py:159: RuntimeWarning: Couldn't reach some vertices at c:\projects\python-igraph-jst2e\vendor\build\igraph\igraph-0.9.0-pre+0afacadd-msvc\src\structural_properties.c:768
#   tgt_vertices.append(cwn_v)

# %%
mesh.draw_igraph(testG)
